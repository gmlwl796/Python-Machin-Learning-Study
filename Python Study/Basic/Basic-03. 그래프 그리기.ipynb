# %% [markdown]
# # 앤스콤 데이터를 통한 시각화의 중요성

# %% [markdown]
# ## 앤스콤 데이터 집합 불러오기

# %%
## seaborn(씨본) 패키지(라이브러리)에 들어 있는 anscombe 예제데이터셋 로딩
import seaborn as sns

# %%
anscombe = sns.load_dataset("anscombe") 
print(anscombe)
print(type(anscombe))
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
anscombe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 3 columns):
# dataset    44 non-null object
# x          44 non-null float64
# y          44 non-null float64
# dtypes: float64(2), object(1)
# memory usage: 1.1+ KB

# %%
anscombe.describe(include = 'all')
# Out:
#        dataset          x          y
# count       44  44.000000  44.000000
# unique       4        NaN        NaN
# top         II        NaN        NaN
# freq        11        NaN        NaN
# mean       NaN   9.000000   7.500682
# std        NaN   3.198837   1.958925
# min        NaN   4.000000   3.100000
# 25%        NaN   7.000000   6.117500
# 50%        NaN   8.000000   7.520000
# 75%        NaN  11.000000   8.747500
# max        NaN  19.000000  12.740000

# %%
# dataset 변수컬럼에 'I'라고 표시된 1번 그룹 서브셋 별도추출
sub1 = anscombe[anscombe['dataset'] == 'I']
sub1
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68

# %%
# 간단한 시각화
# %matplotlib inline

# 다음 2가지 방법중에 임포트하면 됨
import matplotlib.pyplot as plt
from matplotlib import pyplot as plt

# %%
# %whos
# Out:
# Variable   Type         Data/Info
# ---------------------------------
# anscombe   DataFrame       dataset     x      y\n<...>\n43      IV   8.0   6.89
# plt        module       <module 'matplotlib.pyplo<...>\\matplotlib\\pyplot.py'>
# sns        module       <module 'seaborn' from 'C<...>s\\seaborn\\__init__.py'>
# sub1       DataFrame       dataset     x      y\n<...>\n10       I   5.0   5.68

# %%
# .plot() 함수로 기본그래프 그리기
plt.plot(sub1['x'], sub1['y'])

# %% [markdown]
# ###### https://matplotlib.org/api/markers_api.html 내용참고

# %%
# .plot() 함수로 그래프 그리기 'o': 점으로 표현
myplot = plt.plot(sub1['x'], sub1['y'], 'o')

# %%
# 다른 데이터셋 추출
sub2 = anscombe[anscombe['dataset'] == 'II'] 
sub3 = anscombe[anscombe['dataset'] == 'III'] 
sub4 = anscombe[anscombe['dataset'] == 'IV']

# %%
# 4개 데이터셋의 raw데이터는 다르지만, 기술통계량은 동일함
# 같은 모집단에서 추출한 동일한 표본으로 오해할 소지가 있음

# %%
sub1.describe()
# Out:
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.031568
# min     4.000000   4.260000
# 25%     6.500000   6.315000
# 50%     9.000000   7.580000
# 75%    11.500000   8.570000
# max    14.000000  10.840000

# %%
sub2.describe()
# Out:
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.031657
# min     4.000000   3.100000
# 25%     6.500000   6.695000
# 50%     9.000000   8.140000
# 75%    11.500000   8.950000
# max    14.000000   9.260000

# %%
sub3.describe()
# Out:
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500000
# std     3.316625   2.030424
# min     4.000000   5.390000
# 25%     6.500000   6.250000
# 50%     9.000000   7.110000
# 75%    11.500000   7.980000
# max    14.000000  12.740000

# %%
sub4.describe()
# Out:
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.030579
# min     8.000000   5.250000
# 25%     8.000000   6.170000
# 50%     8.000000   7.040000
# 75%     8.000000   8.190000
# max    19.000000  12.500000

# %%
anscombe.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
# 각 그룹별 집계(aggregattion)연산을 통해 
# 각 변수별 평균값이 동일하다는 것을 알 수 있음 
anscombe.groupby('dataset')[['x', 'y']].mean()
# Out:
#            x         y
# dataset
# I        9.0  7.500909
# II       9.0  7.500909
# III      9.0  7.500000
# IV       9.0  7.500909

# %%
# 각 그룹별 집계(aggregattion)연산을 통해 
# 각 변수별 표준편차가 동일하다는 것을 알 수 있음 
anscombe.groupby('dataset')[['x', 'y']].std()
# Out:
#                 x         y
# dataset
# I        3.316625  2.031568
# II       3.316625  2.031657
# III      3.316625  2.030424
# IV       3.316625  2.030579

# %% [markdown]
# ## anscombe 4개 서브셋간 시각화로 상호비교

# %%
# 전체그래프가 위치할 기본프레임 설정
fig = plt.figure()

# %%
# 기본프레임에 그래프 격자로 서브플롯영역을 설정
axes1 = fig.add_subplot(2, 2, 1)
axes2 = fig.add_subplot(2, 2, 2)
axes3 = fig.add_subplot(2, 2, 3)
axes4 = fig.add_subplot(2, 2, 4)

# %%
# 각 격자에 서브플롯 그래프를 하나씩 추가
# (왼쪽 --> 오른쪽방향, 위에서 --> 아래방향)
axes1.plot(sub1['x'], sub1['y'], 'o') 
axes2.plot(sub2['x'], sub2['y'], 'o') 
axes3.plot(sub3['x'], sub3['y'], 'o') 
axes4.plot(sub4['x'], sub4['y'], 'o')

# %%
# 그래프객체 그리기
fig

# %%
# 각 서브플롯 제목설정
axes1.set_title("sub1") 
axes2.set_title("sub2")
axes3.set_title("sub3") 
axes4.set_title("sub4")

fig

# %%
# 메인 제목 설정
fig.suptitle("Anscombe Data")

fig

# %%
# 겹쳐진 부분이 있을 때 해결
fig.tight_layout()

fig

# %% [markdown]
# # 기초 그래프 그리기 ― 히스토그램, 산점도, 박스 그래프

# %%
# seaborn(씨본) 패키지(라이브러리)에 속한 예제데이터셋 중의 'tips' 로딩
# 특정 식당에서 팁을 지불한 손님정보데이터
tips = sns.load_dataset("tips") 
print(tips.head())
print(type(tips))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# <class 'pandas.core.frame.DataFrame'>

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.2 KB

# %%
tips.describe(include = 'all')
# Out:
#         total_bill         tip   sex smoker  day    time        size
# count   244.000000  244.000000   244    244  244     244  244.000000
# unique         NaN         NaN     2      2    4       2         NaN
# top            NaN         NaN  Male     No  Sat  Dinner         NaN
# freq           NaN         NaN   157    151   87     176         NaN
# mean     19.785943    2.998279   NaN    NaN  NaN     NaN    2.569672
# std       8.902412    1.383638   NaN    NaN  NaN     NaN    0.951100
# min       3.070000    1.000000   NaN    NaN  NaN     NaN    1.000000
# 25%      13.347500    2.000000   NaN    NaN  NaN     NaN    2.000000
# 50%      17.795000    2.900000   NaN    NaN  NaN     NaN    2.000000
# 75%      24.127500    3.562500   NaN    NaN  NaN     NaN    3.000000
# max      50.810000   10.000000   NaN    NaN  NaN     NaN    6.000000

# %% [markdown]
# ### 히스토그램 그리기

# %%
# 전체그래프가 위치할 기본프레임 설정
fig = plt.figure() 

# 기본프레임에 그래프 격자로 서브플롯영역을 설정
axes1 = fig.add_subplot(1, 1, 1) 

# 특정 서브플롯에 대해 세부옵션으로 구현
axes1.hist(tips['total_bill'], bins=10) 
axes1.set_title('Histogram of Total Bill')
axes1.set_xlabel('Frequency') 
axes1.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %%
# 특정그래프가 위치할 기본프레임 설정
myhist, ax = plt.subplots()

# 기본 그래프 그리기
ax.hist(tips['total_bill'], bins=10) 

# 그래프 세부옵션 조정
ax.set_title('Histogram of Total Bill')
ax.set_xlabel('Frequency') 
ax.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %%
# fig로 명명한 객체로 그래프 출력
ax.figure

# %%
# myhist라고 명명한 별칭 객체로 그래프 출력
myhist

# %% [markdown]
# ### 산점도 그리기

# %%
# 전체그래프가 위치할 기본프레임 설정
scatter_plot = plt.figure() 

# 기본프레임에 그래프 격자로 서브플롯영역을 설정
axes1 = scatter_plot.add_subplot(1, 1, 1) 

# 특정 서브플롯에 대해 세부옵션으로 구현
axes1.scatter(tips['total_bill'], tips['tip']) 
axes1.set_title('Scatterplot of Total Bill vs Tip') 
axes1.set_xlabel('Total Bill') 
axes1.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
# ### 박스플로 그리기

# %%
# 전체그래프가 위치할 기본프레임 설정
boxplot = plt.figure() 

# 기본프레임에 그래프 격자로 서브플롯영역을 설정
axes1 = boxplot.add_subplot(1, 1, 1) 

# 특정 서브플롯에 대해 세부옵션으로 구현
axes1.boxplot(tips['tip'], 
              labels=['all'], notch=True, vert = True,
              flierprops=dict(markerfacecolor='g', marker='D'))

axes1.set_ylabel('Tip') 
axes1.set_title('Boxplot of Tips')
# Out:
# Text(0.5, 1.0, 'Boxplot of Tips')

# %%
# 박스플롯 그림객체 재조회
boxplot

# %%
# 직접 그리기
plt.boxplot(tips['tip'], 
              labels=['all'], notch=True, vert = True,
              flierprops=dict(markerfacecolor='g', marker='D'))
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d19427da58>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1d194284128>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1d19427d908>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d1942847b8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d194284b00>],
#  'means': []}

# %%
# 전체그래프가 위치할 기본프레임 설정
boxplot_sex = plt.figure() 

# 기본프레임에 그래프 격자로 서브플롯영역을 설정
axes1 = boxplot_sex.add_subplot(1, 1, 1) 

# 특정 서브플롯에 대해 세부옵션으로 구현
axes1.boxplot( 
    [tips[tips['sex'] == 'Female']['tip'], 
     tips[tips['sex'] == 'Male']['tip']], 
    labels=['Female', 'Male'])

axes1.set_xlabel('Sex') 
axes1.set_ylabel('Tip') 
axes1.set_title('Boxplot of Tips by Sex')
# Out:
# Text(0.5, 1.0, 'Boxplot of Tips by Sex')

# %%
# 박스플롯 객체 재조회
boxplot_sex

# %%
# 직접 그리기
plt.boxplot( 
    [tips[tips['sex'] == 'Female']['tip'], 
     tips[tips['sex'] == 'Male']['tip']], 
    labels=['Female', 'Male'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d194344518>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1d194344ba8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1d1943443c8>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1d19434b278>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1d19434b5c0>,
# ...
#  'means': []}

# %% [markdown]
# # 다변량 데이터로 그래프 그리기 ─ 산점도 그래프

# %%
# 결제금액(total_bill)과 팁금액(tip) 관계 산점도에
# 제3의 변수인 성별(sex)이나 테이블당 인원수(size) 변수까지 반영한 다변량 그래프

# matplot에서 색상표시를 데이터에 존재하는 숫자를 읽어서 자동으로 구현해줌
# 데이터에 문자열로 있는 경우 이를 정수숫자로 변환해 색상 인풋값으로 사용하고자 함 

# 성별변수컬럼의 문자열 레이블을 숫자로 변환해주는 사용자정의함수
def recode_sex(sex):
    if sex == 'Female':
        return 0 
    else:
        return 1

# %%
# 성별 레이블을 숫자로 변환해 파생변수로 만들어 기존데이터셋에 추가함
tips['sex_color'] = tips['sex'].apply(recode_sex)
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size sex_color
# 0       16.99  1.01  Female     No  Sun  Dinner     2         0
# 1       10.34  1.66    Male     No  Sun  Dinner     3         1
# 2       21.01  3.50    Male     No  Sun  Dinner     3         1
# 3       23.68  3.31    Male     No  Sun  Dinner     2         1
# 4       24.59  3.61  Female     No  Sun  Dinner     4         0

# %%
# 전체그래프가 위치할 기본프레임 설정
scatter_plot = plt.figure() 

# 기본프레임에 그래프 격자로 서브플롯영역을 설정
axes1 = scatter_plot.add_subplot(1, 1, 1)

# 특정 서브플롯에 대해 세부옵션으로 구현
# - 기존 결제금액(total_bill)과 팁금액(tip) 관계 산점도에
#   제3의 변수인 테이블당 인원수(size)변수까지 반영한 그래프
axes1.scatter(
    x = tips['total_bill'], 
    y = tips['tip'],    
    s = tips['size'] * 10, # s: 점의 크기(size)   
    c = tips['sex_color'], # c: 점의 색상(color)
    alpha = 0.5) # 점의 투명도

axes1.set_title('Total Bill vs Tip Colored by Sex and Sized by Size') 
axes1.set_xlabel('Total Bill') 
axes1.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
# 저장된 그래프 객체 출력
scatter_plot

# %%
# 저장된 그래프 객체 출력
axes1.figure

# %% [markdown]
# # seaborn 라이브러리 사용하기

# %% [markdown]
# ## 단변량 그래프 그리기 ― 히스토그램

# %%
# seaborn(씨본) 패키지(라이브러리) 로딩
import seaborn as sns

# 소속 예제데이터셋 tips 로딩
tips = sns.load_dataset("tips")

# %%
# 특정그래프가 위치할 기본프레임 설정
hist_kde, ax = plt.subplots() 

# 기본 그래프 그리기
ax = sns.distplot(tips['total_bill']) 

# 그래프 세부옵션 조정
ax.set_title('Total Bill Histogram with Density Plot')
# Out:
# C:\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0.5, 1.0, 'Total Bill Histogram with Density Plot')

# %%
# 기본객체로 설정한 ax객체에 들어 있는 그래프 출력
ax.figure

# %%
# 별칭으로 설정한 hist_kde객체에 들어 있는 그래프 출력
hist_kde

# %%
# 특정그래프가 위치할 기본프레임 설정
hist, ax = plt.subplots() 

# 기본 그래프 그리기
ax = sns.distplot(tips['total_bill'], kde = False)
# - 주어진 데이터를 정규화해 넓이가 1인 곡선이 되도록한 
#   커널밀도곡선 옵션 제외

# 그래프 세부옵션 조정
ax.set_title('Total Bill Histogram') 
ax.set_xlabel('Total Bill') 
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# 특정그래프가 위치할 기본프레임 설정
kde, ax = plt.subplots() 

# 기본 그래프 그리기
ax = sns.distplot(tips['total_bill'], hist = False) 
# - 밀도곡선만 나타내기 위해 히스토그램을 제외시킴

# 그래프 세부옵션 조정
ax.set_title('Total Bill Density') 
ax.set_xlabel('Total Bill') 
ax.set_ylabel('Unit Probability')
# Out:
# Text(0, 0.5, 'Unit Probability')

# %%
# 특정그래프가 위치할 기본프레임 설정
hist_kde_rug, ax = plt.subplots() 

# 기본 그래프 그리기
ax = sns.distplot(tips['total_bill'], rug = True) 
# - 양탄자(깔개) 그림을 추가해 데이터 밀집도를 압축해서 표현

# 그래프 세부옵션 조정
ax.set_title('Total Bill Histogram with Density and Rug Plot') 
ax.set_xlabel('Total Bill')
# Out:
# Text(0.5, 0, 'Total Bill')

# %%
# 특정그래프가 위치할 기본프레임 설정
bar, ax = plt.subplots() 

# 기본 그래프 그리기
ax = sns.countplot('day', data = tips) 

# 그래프 세부옵션 조정
ax.set_title('Count of days') 
ax.set_xlabel('Day of the Week') 
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ## 다양한 종류의 이변량 그래프 그리기

# %% [markdown]
# ### seaborn 라이브러리로 산점도 그래프 그리기

# %%
# 특정그래프가 위치할 기본프레임 설정
regression, ax = plt.subplots() 

# 기본 그래프 그리기
ax = sns.regplot(x='total_bill', y='tip', data=tips, fit_reg=True) 

# 그래프 세부옵션 조정
ax.set_title('Scatterplot of Total Bill and Tip') 
ax.set_xlabel('Total Bill') 
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
# 저장된 그래프 객체 출력
regression

# %%
# 저장된 그래프 객체 출력
ax.figure

# %%
# 기본 그래프 그리기
joint = sns.jointplot(x='total_bill', y='tip', data=tips) 

# 그래프 세부옵션 조정
joint.set_axis_labels(xlabel='Total Bill', ylabel='Tip')
joint.fig.suptitle('Joint Plot of Total Bill and Tip', fontsize=10, y=1.03)
# Out:
# Text(0.5, 1.03, 'Joint Plot of Total Bill and Tip')

# %%
joint

# %%
joint.fig

# %%
# 기본 그래프 그리기
hexbin = sns.jointplot(x="total_bill", y="tip", data=tips, kind="hex")

# 그래프 세부옵션 조정
hexbin.set_axis_labels(xlabel='Total Bill', ylabel='Tip')
hexbin.fig.suptitle('Hexbin Joint Plot of Total Bill and Tip', fontsize=10, y=1.03)
# Out:
# Text(0.5, 1.03, 'Hexbin Joint Plot of Total Bill and Tip')

# %% [markdown]
# ### 이차원 밀집도 그리기

# %%
kde, ax = plt.subplots() 

# 기본 그래프 그리기
ax = sns.kdeplot(data=tips['total_bill'],
                 data2=tips['tip'], 
                 shade=True)
ax.set_title('Kernel Density Plot of Total Bill and Tip') 
ax.set_xlabel('Total Bill') 
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
# ### 바 그래프 그리기

# %%
ax = plt.subplots() 
ax = sns.barplot(x='time', y='total_bill', data=tips) 
ax.set_title('Bar plot of average total bill for time of day') 
ax.set_xlabel('Time of day') 
ax.set_ylabel('Average total bill')
# Out:
# Text(0, 0.5, 'Average total bill')

# %% [markdown]
# ### 박스 그래프 그리기

# %%
ax = plt.subplots() 
ax = sns.boxplot(x='time', y='total_bill', data=tips) 
ax.set_title('Boxplot of total bill by time of day') 
ax.set_xlabel('Time of day') 
ax.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %%
ax = plt.subplots() 
ax = sns.violinplot(x='time', y='total_bill', data=tips) 
ax.set_title('Violin plot of total bill by time of day') 
ax.set_xlabel('Time of day') 
ax.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %% [markdown]
# ### 산점도 매트릭스 그리기

# %%
fig = sns.pairplot(tips)

# %% [markdown]
# ### 산점도 매트릭스: 위/아래 삼각행렬과 대각행열별 그래프 그리기

# %%
pair_grid = sns.PairGrid(tips) 
pair_grid = pair_grid.map_upper(sns.regplot) 
pair_grid = pair_grid.map_lower(sns.kdeplot) 
pair_grid = pair_grid.map_diag(sns.distplot, rug=True)

# %%
plt.show()

# %% [markdown]
# # seaborn 라이브러리로 다변량(제3의 변수 결합) 그래프 그리기

# %% [markdown]
# ### 바이올린 그래프 그리기 ― 색상으로 제3의 변수(sex) 추가투입

# %%
violin, ax = plt.subplots() 
ax = sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True) 
plt.show()

# %% [markdown]
# ### 산점도, 관계 그래프 그리기 ― 색상으로 제3의 변수(sex) 추가투입

# %%
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', fit_reg=True) 
plt.show()

# %% [markdown]
# ### 산점도 매트릭스 ― 색상으로 제3의 변수(sex) 추가투입

# %%
fig = sns.pairplot(tips, hue='sex')
plt.show()

# %% [markdown]
# ### 산점도 그래프의 크기와 모양 조절하기

# %%
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, hue='sex', scatter_kws={'s': tips['size']*10}) 
plt.show()

# %%
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, hue='sex', markers=['o', 'x'], scatter_kws={'s': tips['size']*10}) 
plt.show()

# %% [markdown]
# ### lmplot 메서드로 4개의 데이터 그룹에 대한 그래프 한 번에 그리기

# %%
anscombe_plot = sns.lmplot(x='x', y='y', data=anscombe, fit_reg=False)

# %%
anscombe_plot = sns.lmplot(x='x', y='y', data=anscombe, fit_reg=False, col='dataset', col_wrap=2)

# %% [markdown]
# # FacetGrid 클래스로도 그룹별 그래프 작성

# %%
facet = sns.FacetGrid(tips, col='time') 
facet.map(sns.distplot, 'total_bill', rug=True)

# %%
facet = sns.FacetGrid(tips, col='day', hue='sex') 
facet = facet.map(plt.scatter, 'total_bill', 'tip') 
facet = facet.add_legend()

# %%
facet = sns.FacetGrid(tips, col='time', row='smoker', hue='sex') 
facet.map(plt.scatter, 'total_bill', 'tip')

# %% [markdown]
# # 데이터프레임과 시리즈로 그래프 그리기

# %%
fig, ax = plt.subplots()
ax = tips['total_bill'].plot.hist()

# %%
fig, ax = plt.subplots() 
ax = tips[['total_bill', 'tip']].plot.hist(alpha=0.5, bins=20, ax=ax)

# %%
fig, ax = plt.subplots() 
ax = tips['tip'].plot.kde()

# %%
fig, ax = plt.subplots() 
ax = tips.plot.scatter(x='total_bill', y='tip', ax=ax)

# %%
fig, ax = plt.subplots() 
ax = tips.plot.hexbin(x='total_bill', y='tip', ax=ax)

# %%
fig, ax = plt.subplots() 
ax = tips.plot.hexbin(x='total_bill', y='tip', gridsize=10, ax=ax)

# %%
fig, ax = plt.subplots() 
ax = tips.plot.box(ax=ax)

# %% [markdown]
# ## 그래프에 스타일 적용하기

# %%
fig, ax = plt.subplots() 
ax = sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)

# %%
sns.set_style('whitegrid') 
fig, ax = plt.subplots() 
ax = sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)

# %%
fig = plt.figure() 
seaborn_styles = ['darkgrid', 'whitegrid', 'dark', 'white', 'ticks'] 
for idx, style in enumerate(seaborn_styles):
    plot_position = idx + 1
    with sns.axes_style(style):
        ax = fig.add_subplot(2, 3, plot_position)
        violin = sns.violinplot(x='time', y='total_bill', data=tips, ax=ax)
        violin.set_title(style) 
        
fig.tight_layout()
